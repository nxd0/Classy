# %% [markdown]
# # Classy Quickstart

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Note:</b> As you can see below, Classy allows anyone to spin up basic ML classification workflow in less than 10 lines of code.
# </div>

# %%
from ipynb.fs.full.Classy import Classy
c = Classy()
# Out:
# ––––––––––––––––––––––––––––––––––––
# Welcome to CLASSY!
# ––––––––––––––––––––––––––––––––––––
#
# Call the about() function to learn more about how CLASSY works.
# OR Call the obtain() function to select your data and get started.

# %%
c.obtain()
# Out:
# ------------------------------------
# Obtaining Your Data
# ------------------------------------
#
# Select The File You Want to Work With
#
# I found 5 CSV files in your directory that we can get started with.
# Which data set do you want to work with?
#
# 1 - demo-iris.csv
# 2 - demo-flightdelays.csv
# 3 - demo-kickstartersuccess.csv
# 4 - demo-banknote_authentication.csv
# 5 - demo-heartdisease.csv
#
# Enter the number of the file
# 5
#
# Identify Target
#
#  1: age  (DType: int64 – NUnique: 41 )
#  2: sex  (DType: int64 – NUnique: 2 )
#  3: cp  (DType: int64 – NUnique: 4 )
#  4: trestbps  (DType: int64 – NUnique: 49 )
#  5: chol  (DType: int64 – NUnique: 152 )
#  6: fbs  (DType: int64 – NUnique: 2 )
#  7: restecg  (DType: int64 – NUnique: 3 )
#  8: thalach  (DType: int64 – NUnique: 91 )
#  9: exang  (DType: int64 – NUnique: 2 )
#  10: oldpeak  (DType: float64 – NUnique: 40 )
#  11: slope  (DType: int64 – NUnique: 3 )
#  12: ca  (DType: int64 – NUnique: 5 )
#  13: thal  (DType: int64 – NUnique: 4 )
#  14: target  (DType: int64 – NUnique: 2 )
# Which of these columns represents the category you are trying to predict? Type in the associated column number below.
# 14
#
# Target Variable Selected = target
#
# Next Steps
#
#
# Great. All set to get started with demo-heartdisease.csv. Call the scrub() function to continue.
#
# You can also explore the unscrubbed dataset by calling the explore() function.
#
# Lastly, If your file is already scrubbed and model ready, you can proceed straight to the  model() function.

# %%
c.explore()

# %%
c.scrub()
# Out:
# ------------------------------------
# Scrubbing Your Data
# ------------------------------------
#
# demo-heartdisease.csv has 14 columns and 303 rows
#
# Step 0. Take a sample (optional)
#
# Skipping this step (since you're dataset isn't overwhelmingly large)
# Step 1. Remove any target values (optional)
#
#
# Your target variable has 2 unique values:
# Value counts in red represent less than 5% of total data (consider removing).
# 1: 1 138
# 2: 0 165
# Would you like to remove of any of these values (and the associated rows)?
# Don't worry about NAN values for now... we'll deal with that later Type (y/n) below
# n
# 1    165
# 0    138
# Name: target, dtype: int64
#
# Step 2. Remove Columns (optional)
#
# 1: age
# 2: sex
# 3: cp
# 4: trestbps
# 5: chol
# 6: fbs
# 7: restecg
# 8: thalach
# 9: exang
# 10: oldpeak
# 11: slope
# 12: ca
# 13: thal
# 14: target
#
# Would you like to remove any of the columns? Type (y/n) below
# n
#
# Step 3. Fixing Column Data Types (optional)
#
# 1: age – DType: int64 – Examples (37, 41, 56)
# 2: sex – DType: int64 – Examples (1, 0, 1)
# 3: cp – DType: int64 – Examples (2, 1, 1)
# 4: trestbps – DType: int64 – Examples (130, 130, 120)
# 5: chol – DType: int64 – Examples (250, 204, 236)
# 6: fbs – DType: int64 – Examples (0, 0, 0)
# 7: restecg – DType: int64 – Examples (1, 0, 1)
# 8: thalach – DType: int64 – Examples (187, 172, 178)
# 9: exang – DType: int64 – Examples (0, 0, 0)
# 10: oldpeak – DType: float64 – Examples (3.5, 1.4, 0.8)
# 11: slope – DType: int64 – Examples (0, 2, 2)
# 12: ca – DType: int64 – Examples (0, 0, 0)
# 13: thal – DType: int64 – Examples (2, 2, 2)
# 14: target – DType: int64 – Examples (1, 1, 1)
#
# Do any of these column datatypes look incorrect? Type (y/n) below
# n
#
# Step 4. Dealing with Any Missing Data
#
# No missing data found... Moving on!
#
# Scrub complete! You can now access your scrubbed X and Y files at OBJECT.x and OBJECT.y respectively.
# Next, call the explore() function to select your data or you can skip straight to the model()function.

# %%
c.explore()
# Out:
# ------------------------------------
# Exploring Your Data
# ------------------------------------
# Please be patient... this may take a minute if you have a lot of data.
# Would you like to do a simple explore (.head, .info, .describe) or an advanced explore (using pandas profiling) Enter 1 for simple, or 2 for advanced.
# 1
#
# Would you like to explore the original dataset, or the scrubbed dataset? Enter 1 for original, or 2 for scrubbed.
# 1
#
# Basic Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB
#
# First 5 Rows
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>age</th>
#       <th>sex</th>
#       <th>cp</th>
#       <th>trestbps</th>
#       <th>chol</th>
#       <th>fbs</th>
#       <th>restecg</th>
#       <th>thalach</th>
#       <th>exang</th>
#       <th>oldpeak</th>
#       <th>slope</th>
#       <th>ca</th>
#       <th>thal</th>
#       <th>target</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>63</td>
#       <td>1</td>
#       <td>3</td>
#       <td>145</td>
#       <td>233</td>
#       <td>1</td>
#       <td>0</td>
#       <td>150</td>
#       <td>0</td>
#       <td>2.3</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>37</td>
#       <td>1</td>
#       <td>2</td>
#       <td>130</td>
#       <td>250</td>
#       <td>0</td>
#       <td>1</td>
#       <td>187</td>
#       <td>0</td>
#       <td>3.5</td>
#       <td>0</td>
#       <td>0</td>
#       <td>2</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>41</td>
#       <td>0</td>
#       <td>1</td>
#       <td>130</td>
#       <td>204</td>
#       <td>0</td>
#       <td>0</td>
#       <td>172</td>
#       <td>0</td>
#       <td>1.4</td>
#       <td>2</td>
#       <td>0</td>
#       <td>2</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>56</td>
#       <td>1</td>
#       <td>1</td>
#       <td>120</td>
#       <td>236</td>
#       <td>0</td>
#       <td>1</td>
#       <td>178</td>
#       <td>0</td>
#       <td>0.8</td>
#       <td>2</td>
#       <td>0</td>
#       <td>2</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>57</td>
#       <td>0</td>
#       <td>0</td>
#       <td>120</td>
#       <td>354</td>
#       <td>0</td>
#       <td>1</td>
#       <td>163</td>
#       <td>1</td>
#       <td>0.6</td>
#       <td>2</td>
#       <td>0</td>
#       <td>2</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
# Descriptive Statistics
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>age</th>
#       <th>sex</th>
#       <th>cp</th>
#       <th>trestbps</th>
#       <th>chol</th>
#       <th>fbs</th>
#       <th>restecg</th>
#       <th>thalach</th>
#       <th>exang</th>
#       <th>oldpeak</th>
#       <th>slope</th>
#       <th>ca</th>
#       <th>thal</th>
#       <th>target</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>303.000000</td>
#       <td>303.000000</td>
#       <td>303.000000</td>
#       <td>303.000000</td>
#       <td>303.000000</td>
#       <td>303.000000</td>
#       <td>303.000000</td>
#       <td>303.000000</td>
#       <td>303.000000</td>
#       <td>303.000000</td>
#       <td>303.000000</td>
#       <td>303.000000</td>
#       <td>303.000000</td>
#       <td>303.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>54.366337</td>
#       <td>0.683168</td>
#       <td>0.966997</td>
#       <td>131.623762</td>
#       <td>246.264026</td>
#       <td>0.148515</td>
#       <td>0.528053</td>
#       <td>149.646865</td>
#       <td>0.326733</td>
#       <td>1.039604</td>
#       <td>1.399340</td>
#       <td>0.729373</td>
#       <td>2.313531</td>
#       <td>0.544554</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>9.082101</td>
#       <td>0.466011</td>
#       <td>1.032052</td>
#       <td>17.538143</td>
#       <td>51.830751</td>
#       <td>0.356198</td>
#       <td>0.525860</td>
#       <td>22.905161</td>
#       <td>0.469794</td>
#       <td>1.161075</td>
#       <td>0.616226</td>
#       <td>1.022606</td>
#       <td>0.612277</td>
#       <td>0.498835</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>29.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>94.000000</td>
#       <td>126.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>71.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>47.500000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>120.000000</td>
#       <td>211.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>133.500000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>2.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>55.000000</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>130.000000</td>
#       <td>240.000000</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>153.000000</td>
#       <td>0.000000</td>
#       <td>0.800000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>2.000000</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>61.000000</td>
#       <td>1.000000</td>
#       <td>2.000000</td>
#       <td>140.000000</td>
#       <td>274.500000</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>166.000000</td>
#       <td>1.000000</td>
#       <td>1.600000</td>
#       <td>2.000000</td>
#       <td>1.000000</td>
#       <td>3.000000</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>77.000000</td>
#       <td>1.000000</td>
#       <td>3.000000</td>
#       <td>200.000000</td>
#       <td>564.000000</td>
#       <td>1.000000</td>
#       <td>2.000000</td>
#       <td>202.000000</td>
#       <td>1.000000</td>
#       <td>6.200000</td>
#       <td>2.000000</td>
#       <td>4.000000</td>
#       <td>3.000000</td>
#       <td>1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
c.model()
# Out:
# ------------------------------------
# Modeling Your Data
# ------------------------------------
#
# Getting dummy variables...
# Pre-Dummy Shape: (303, 13)
# Post-Dummy Shape: (303, 13)
#
# Scaling your data...
# Would you like to normalize (Min-Max scaler) or Standardize (standard scaler) the data?
# Enter 1 for MinMax (Recommended), 2 for Standard Scaler, or 3 to skip.
# 1
# MinMax Scaler Selected
# Scaling complete.
#
# Here are the first 3 rows to confirm the change was successfully made.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#       <th>6</th>
#       <th>7</th>
#       <th>8</th>
#       <th>9</th>
#       <th>10</th>
#       <th>11</th>
#       <th>12</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.708333</td>
#       <td>1.0</td>
#       <td>1.000000</td>
#       <td>0.481132</td>
#       <td>0.244292</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.603053</td>
#       <td>0.0</td>
#       <td>0.370968</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.333333</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.166667</td>
#       <td>1.0</td>
#       <td>0.666667</td>
#       <td>0.339623</td>
#       <td>0.283105</td>
#       <td>0.0</td>
#       <td>0.5</td>
#       <td>0.885496</td>
#       <td>0.0</td>
#       <td>0.564516</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.666667</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.250000</td>
#       <td>0.0</td>
#       <td>0.333333</td>
#       <td>0.339623</td>
#       <td>0.178082</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.770992</td>
#       <td>0.0</td>
#       <td>0.225806</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.666667</td>
#     </tr>
#   </tbody>
# </table>
# Splitting up your train and test data...
#
# Chosing Which Models to Use...
#
# Heads up: Selecting multiple models may result in extreme wait times.
# You can always start with 1-2 models and add more later.
# All models previously run can be compared by calling .interpret() later.
#
# 1 Decision Tree
# 2 Random Forrest
# 3 AdaBoost
# 4 XGBoost
# 5 Linear Support Vector
# 6 Neural Network
#
# Please type in the corrosponding number of each model you want to run, sepparating each number by a space.
# 1 5
# ['Decision Tree', True]
# ['Linear Support Vector', True]
#
# Training Baseline Models
#
# Decision Tree Launching...
# Training Accuracy: 100.0%
# Validation accuracy: 75.0%
#
# Linear Support Vector Launching...
# Training Accuracy: 83.26%
# Validation accuracy: 86.84%
#
# The best performing model was:  Optimized Decision Tree – with a Test Accuracy of:  0.9737
#
# Optimizing Models
#
# Optimizing Decision Tree...
# Grid Search found the following optimal parameters:
# criterion: 'gini'
# max_depth: 10
# min_samples_split: 5
# random_state: 0
# Training Accuracy: 97.8%
# Validation accuracy: 76.32%
# Optimizing Linear SVC...
# Grid Search found the following optimal parameters:
# C: 10
# class_weight: None
# loss: 'hinge'
# max_iter: 2000
# random_state: 0
#
# Training Accuracy: 83.7%
# Validation accuracy: 86.84%
# The best performing model was:  Linear SVC – with a Test Accuracy of:  0.8684
#
# Modeling Complete! Next, call the .interpret() function.

# %%
c.interpret()

# %%
c.predict()
# Out:
# ------------------------------------
# Making a Prediction
# ------------------------------------
#
# Please provide the input values to make a prediction. (MUST be correct data type)
# Value for: age? (Type = int64) (Example = 63)63
# Value for: sex? (Type = int64) (Example = 1)1
# Value for: cp? (Type = int64) (Example = 3)3
# Value for: trestbps? (Type = int64) (Example = 145)145
# Value for: chol? (Type = int64) (Example = 233)233
# Value for: fbs? (Type = int64) (Example = 1)1
# Value for: restecg? (Type = int64) (Example = 0)0
# Value for: thalach? (Type = int64) (Example = 150)150
# Value for: exang? (Type = int64) (Example = 0)0
# Value for: oldpeak? (Type = float64) (Example = 2.3)2.3
# Value for: slope? (Type = int64) (Example = 0)0
# Value for: ca? (Type = int64) (Example = 0)0
# Value for: thal? (Type = int64) (Example = 1)1
#
# Best Performing Model Prediction
# Linear SVC predicts --> 1
#
# All Model Predictions
# Decision Tree predicts --> 1
# Linear SVC predicts --> 1
# Optimized Decision Tree predicts --> 1
# Optimized Linear SVC predicts --> 1
#
# No unique mode found.
