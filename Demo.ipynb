# %% [markdown]
# # Classy Demo

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Note:</b> As you can see below, Classy allows anyone to spin up basic ML classification workflow in less than 10 lines of code.
# </div>

# %%
from ipynb.fs.full.Classy import Classy

# %%
c = Classy()
# Out:
# ––––––––––––––––––––––––––––––––––––
# Welcome to CLASSY!
# ––––––––––––––––––––––––––––––––––––
#
# Call the about() function to learn more about how CLASSY works.
# OR Call the obtain() function to select your data and get started.

# %%
c.obtain()
# Out:
# ------------------------------------
# Obtaining Your Data
# ------------------------------------
#
# Select The File You Want to Work With
#
# I found 5 CSV files in your directory that we can get started with.
# Which data set do you want to work with?
#
# 1 - demo-iris.csv
# 2 - demo-flightdelays.csv
# 3 - demo-kickstartersuccess.csv
# 4 - demo-banknote_authentication.csv
# 5 - demo-heartdisease.csv
#
# Enter the number of the file
# 2
#
# Identify Target
#
#  1: DAY_OF_MONTH  (DType: int64 – NUnique: 31 )
#  2: DAY_OF_WEEK  (DType: int64 – NUnique: 7 )
#  3: OP_UNIQUE_CARRIER  (DType: object – NUnique: 17 )
#  4: OP_CARRIER_AIRLINE_ID  (DType: int64 – NUnique: 17 )
#  5: OP_CARRIER  (DType: object – NUnique: 17 )
#  6: TAIL_NUM  (DType: object – NUnique: 5444 )
#  7: OP_CARRIER_FL_NUM  (DType: int64 – NUnique: 6720 )
#  8: ORIGIN_AIRPORT_ID  (DType: int64 – NUnique: 351 )
#  9: ORIGIN_AIRPORT_SEQ_ID  (DType: int64 – NUnique: 351 )
#  10: ORIGIN  (DType: object – NUnique: 351 )
#  11: DEST_AIRPORT_ID  (DType: int64 – NUnique: 350 )
#  12: DEST_AIRPORT_SEQ_ID  (DType: int64 – NUnique: 350 )
#  13: DEST  (DType: object – NUnique: 350 )
#  14: DEP_TIME  (DType: float64 – NUnique: 1432 )
#  15: DEP_DEL15  (DType: float64 – NUnique: 2 )
#  16: DEP_TIME_BLK  (DType: object – NUnique: 19 )
#  17: ARR_TIME  (DType: float64 – NUnique: 1440 )
#  18: ARR_DEL15  (DType: float64 – NUnique: 2 )
#  19: CANCELLED  (DType: float64 – NUnique: 2 )
#  20: DIVERTED  (DType: float64 – NUnique: 2 )
#  21: DISTANCE  (DType: float64 – NUnique: 1471 )
#  22: Unnamed: 21  (DType: float64 – NUnique: 0 )
# Which of these columns represents the category you are trying to predict? Type in the associated column number below.
# 18
#
# Target Variable Selected = ARR_DEL15
#
# Next Steps
#
#
# Great. All set to get started with demo-flightdelays.csv. Call the scrub() function to continue.
#
# You can also explore the unscrubbed dataset by calling the explore() function.
#
# Lastly, If your file is already scrubbed and model ready, you can proceed straight to the  model() function.

# %%
c.scrub()
# Out:
# ------------------------------------
# Scrubbing Your Data
# ------------------------------------
#
# demo-flightdelays.csv has 22 columns and 607346 rows
#
# Step 0. Take a sample (optional)
#
# Looks like your working with a LOT of data! That's great, but...
# Sometimes that can make our models take a long time to run on a regular computer.
# Would you like to take a smaller sample of the data to speed things up? Type (y/n) below
# y
# What sized sample? (I recommend starting with ~50K rows) Type a number below.
# 3000
# Step 1. Remove any target values (optional)
#
#
# Your target variable has 2 unique values:
# Value counts in red represent less than 5% of total data (consider removing).
# 1: 0.0 2554
# 2: 1.0 406
# 3: nan  40
# Would you like to remove of any of these values (and the associated rows)?
# Don't worry about NAN values for now... we'll deal with that later Type (y/n) below
# n
# 0.0    2554
# 1.0     406
# NaN      40
# Name: ARR_DEL15, dtype: int64
#
# Step 2. Remove Columns (optional)
#
# 1: DAY_OF_MONTH
# 2: DAY_OF_WEEK
# 3: OP_UNIQUE_CARRIER
# 4: OP_CARRIER_AIRLINE_ID
# 5: OP_CARRIER
# 6: TAIL_NUM
# 7: OP_CARRIER_FL_NUM
# 8: ORIGIN_AIRPORT_ID
# 9: ORIGIN_AIRPORT_SEQ_ID
# 10: ORIGIN
# 11: DEST_AIRPORT_ID
# 12: DEST_AIRPORT_SEQ_ID
# 13: DEST
# 14: DEP_TIME
# 15: DEP_DEL15
# 16: DEP_TIME_BLK
# 17: ARR_TIME
# 18: ARR_DEL15
# 19: CANCELLED
# 20: DIVERTED
# 21: DISTANCE
# 22: Unnamed: 21
#
# Would you like to remove any of the columns? Type (y/n) below
# y
# Please type in the number of each column you want to remove, sepparating each number by a space.
# 3 4 8 9 11 12 16 17 22
# 9 columns were successfully removed.
#
# Step 3. Fixing Column Data Types (optional)
#
# 1: DAY_OF_MONTH – DType: int64 – Examples (19, 24, 11)
# 2: DAY_OF_WEEK – DType: int64 – Examples (7, 5, 6)
# 3: OP_CARRIER – DType: object – Examples (B6, UA, AA)
# 4: TAIL_NUM – DType: object – Examples (N625JB, N462UA, N393AN)
# 5: OP_CARRIER_FL_NUM – DType: int64 – Examples (131, 2243, 1623)
# 6: ORIGIN – DType: object – Examples (MCO, MSY, MIA)
# 7: DEST – DType: object – Examples (LAX, SFO, PHL)
# 8: DEP_TIME – DType: float64 – Examples (1256.0, 1646.0, 721.0)
# 9: DEP_DEL15 – DType: float64 – Examples (1.0, 0.0, 1.0)
# 10: ARR_DEL15 – DType: float64 – Examples (0.0, 0.0, nan)
# 11: CANCELLED – DType: float64 – Examples (0.0, 0.0, 0.0)
# 12: DIVERTED – DType: float64 – Examples (0.0, 0.0, 1.0)
# 13: DISTANCE – DType: float64 – Examples (2218.0, 1911.0, 1013.0)
#
# Do any of these column datatypes look incorrect? Type (y/n) below
# n
#
# Step 4. Dealing with Any Missing Data
#
# The following columns have missing data we have to deal with before modelling.
# For each, you can choose how to handle the missing data.
#
# 4: TAIL_NUM – Missing Data Count: 3 / 3000
# For this column, would you like to...
# 	1. REMOVE the missing rows from the data set.
# 	2. REPLACE this data with the median value for numerical data or most common for categorical data)
# 	3. KEEP the data as is (for categorical data only)
# Type in the assocated number to make your choice:
# 1
# Missing data was removed.
#
# 8: DEP_TIME – Missing Data Count: 31 / 2997
# For this column, would you like to...
# 	1. REMOVE the missing rows from the data set.
# 	2. REPLACE this data with the median value for numerical data or most common for categorical data)
# 	3. KEEP the data as is (for categorical data only)
# Type in the assocated number to make your choice:
# 1
# Missing data was removed.
#
# 10: ARR_DEL15 – Missing Data Count: 6 / 2966
# For this column, would you like to...
# 	1. REMOVE the missing rows from the data set.
# 	2. REPLACE this data with the median value for numerical data or most common for categorical data)
# 	3. KEEP the data as is (for categorical data only)
# Type in the assocated number to make your choice:
# 1
# Missing data was removed.
#
#
# Scrub complete! You can now access your scrubbed X and Y files at OBJECT.x and OBJECT.y respectively.
# Next, call the explore() function to select your data or you can skip straight to the model()function.

# %%
c.model()
# Out:
# ------------------------------------
# Modeling Your Data
# ------------------------------------
#
# Getting dummy variables...
# Pre-Dummy Shape: (2960, 12)
# Post-Dummy Shape: (2960, 2724)
#
# Scaling your data...
# Would you like to normalize (Min-Max scaler) or Standardize (standard scaler) the data?
# Enter 1 for MinMax (Recommended), 2 for Standard Scaler, or 3 to skip.
# 1
# MinMax Scaler Selected
# Scaling complete.
#
# Here are the first 3 rows to confirm the change was successfully made.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#       <th>6</th>
#       <th>7</th>
#       <th>8</th>
#       <th>9</th>
#       <th>10</th>
#       <th>11</th>
#       <th>12</th>
#       <th>13</th>
#       <th>14</th>
#       <th>15</th>
#       <th>16</th>
#       <th>17</th>
#       <th>18</th>
#       <th>19</th>
#       <th>20</th>
#       <th>21</th>
#       <th>22</th>
#       <th>23</th>
#       <th>24</th>
#       <th>25</th>
#       <th>26</th>
#       <th>27</th>
#       <th>28</th>
#       <th>29</th>
#       <th>30</th>
#       <th>31</th>
#       <th>32</th>
#       <th>33</th>
#       <th>34</th>
#       <th>35</th>
#       <th>36</th>
#       <th>37</th>
#       <th>38</th>
#       <th>39</th>
#       <th>40</th>
#       <th>41</th>
#       <th>42</th>
#       <th>43</th>
#       <th>44</th>
#       <th>45</th>
#       <th>46</th>
#       <th>47</th>
#       <th>48</th>
#       <th>49</th>
#       <th>50</th>
#       <th>51</th>
#       <th>52</th>
#       <th>53</th>
#       <th>54</th>
#       <th>55</th>
#       <th>56</th>
#       <th>57</th>
#       <th>58</th>
#       <th>59</th>
#       <th>60</th>
#       <th>61</th>
#       <th>62</th>
#       <th>63</th>
#       <th>64</th>
#       <th>65</th>
#       <th>66</th>
#       <th>67</th>
#       <th>68</th>
#       <th>69</th>
#       <th>70</th>
#       <th>71</th>
#       <th>72</th>
#       <th>73</th>
#       <th>74</th>
#       <th>75</th>
#       <th>76</th>
#       <th>77</th>
#       <th>78</th>
#       <th>79</th>
#       <th>80</th>
#       <th>81</th>
#       <th>82</th>
#       <th>83</th>
#       <th>84</th>
#       <th>85</th>
#       <th>86</th>
#       <th>379</th>
#       <th>380</th>
#       <th>381</th>
#       <th>382</th>
#       <th>383</th>
#       <th>384</th>
#       <th>385</th>
#       <th>386</th>
#       <th>387</th>
#       <th>388</th>
#       <th>389</th>
#       <th>390</th>
#       <th>391</th>
#       <th>392</th>
#       <th>393</th>
#       <th>394</th>
#       <th>395</th>
#       <th>396</th>
#       <th>397</th>
#       <th>398</th>
#       <th>399</th>
#       <th>400</th>
#       <th>401</th>
#       <th>402</th>
#       <th>403</th>
#       <th>404</th>
#       <th>405</th>
#       <th>406</th>
#       <th>407</th>
#       <th>408</th>
#       <th>409</th>
#       <th>410</th>
#       <th>411</th>
#       <th>412</th>
#       <th>413</th>
#       <th>414</th>
#       <th>415</th>
#       <th>416</th>
#       <th>417</th>
#       <th>418</th>
#       <th>419</th>
#       <th>420</th>
#       <th>42
# Splitting up your train and test data...
#
# Chosing Which Models to Use...
#
# Heads up: Selecting multiple models may result in extreme wait times.
# You can always start with 1-2 models and add more later.
# All models previously run can be compared by calling .interpret() later.
#
# 1 Decision Tree
# 2 Random Forrest
# 3 AdaBoost
# 4 XGBoost
# 5 Linear Support Vector
# 6 Neural Network
#
# Please type in the corrosponding number of each model you want to run, sepparating each number by a space.
# 1 2 3 5
# ['Decision Tree', True]
# ['Random Forrest', True]
# ['AdaBoost', True]
# ['Linear Support Vector', True]
#
# Training Baseline Models
#
# Decision Tree Launching...
# Training Accuracy: 100.0%
# Validation accuracy: 92.43%
#
# Random Forrest Launching...
# Training Accuracy: 98.92%
# Validation accuracy: 91.22%
#
# Adaboost Launching...
# Training Accuracy: 94.32%
# Validation accuracy: 93.92%
#
# Linear Support Vector Launching...
# Training Accuracy: 99.73%
# Validation accuracy: 93.11%
#
# The best performing model was:  Adaboost – with a Test Accuracy of:  0.9392
#
# Optimizing Models
#
# Optimizing Decision Tree...
# Grid Search found the following optimal parameters:
# criterion: 'gini'
# max_depth: 10
# min_samples_split: 5
# random_state: 0
# Training Accuracy: 96.04%
# Validation accuracy: 93.24%
# Optimizing Random Forrest...
# Grid Search found the following optimal parameters:
# max_depth: 500
# n_estimators: 500
# random_state: 0
# Training Accuracy: 100.0%
# Validation accuracy: 93.92%
# Optimizing AdaBoost...
# Grid Search found the following optimal parameters:
# learning_rate: 0.1
# n_estimators: 10
# random_state: 0
#
# Training Accuracy: 93.42%
# Validation accuracy: 94.73%
# Optimizing Linear SVC...
# Grid Search found the following optimal parameters:
# C: 1
# class_weight: None
# loss: 'hinge'
# max_iter: 1000
# random_state: 0
#
# Training Accuracy: 98.42%
# Validation accuracy: 93.65%
# The best performing model was:  Optimized AdaBoost – with a Test Accuracy of:  0.9473
#
# Modeling Complete! Next, call the .interpret() function.

# %%
c.interpret()
# Out:
# ------------------------------------
# Interpreting Your Results
# ------------------------------------
# The best performing model was:  Optimized AdaBoost – with a Test Accuracy of:  0.9473

# %%
c.predict()
